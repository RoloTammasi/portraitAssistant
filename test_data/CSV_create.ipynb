# %%
import pandas as pd

# %%
def create_QR()

# %%
# import CSV of students
students = pd.read_csv("sj_sample.csv")
students.head() # prints a sample of the data
# Out:
#   Last name First name Middle name  Current Grade Current status  Student ID  \
# 0    Abbott   Geoffrey      Robert             11       Enrolled       21996
# 1      Abiy      Nahom    Wonderad              9       Enrolled       22342
# 2    Abrell      Mason         NaN              9       Enrolled       22343
# 3   Aceituj   Benjamin     Ricardo             10       Enrolled       22018
# 4    Acosta      Cielo     Antonio              9       Enrolled       22819
#
#   Barcode Alpha description
# 0                     CLCJF
# 1                     QVLJZ
# 2                     JXFGC
# 3                     XTYCN
# 4                     OISQT

# %%
students = students.drop("Barcode Alpha description", 1)
students.head()
# Out:
#   Last name First name Middle name  Current Grade Current status  Student ID
# 0    Abbott   Geoffrey      Robert             11       Enrolled       21996
# 1      Abiy      Nahom    Wonderad              9       Enrolled       22342
# 2    Abrell      Mason         NaN              9       Enrolled       22343
# 3   Aceituj   Benjamin     Ricardo             10       Enrolled       22018
# 4    Acosta      Cielo     Antonio              9       Enrolled       22819

# %%
students["QR Code"] = "QR Code"
students.head()
# Out:
#   Last name First name Middle name  Current Grade Current status  Student ID  \
# 0    Abbott   Geoffrey      Robert             11       Enrolled       21996
# 1      Abiy      Nahom    Wonderad              9       Enrolled       22342
# 2    Abrell      Mason         NaN              9       Enrolled       22343
# 3   Aceituj   Benjamin     Ricardo             10       Enrolled       22018
# 4    Acosta      Cielo     Antonio              9       Enrolled       22819
#
#    QR Code
# 0  QR Code
# 1  QR Code
# 2  QR Code
# 3  QR Code
# 4  QR Code
